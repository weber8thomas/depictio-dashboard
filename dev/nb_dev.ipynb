# %%
children = [
    {'props': {'children': {'props': {'children': [
                        {'props': {'children': [
                                    {'props': {'children': [
                                                {'props': {'children': {'props': {'options': ['country', 'year', 'pop', 'continent', 'lifeExp', 'gdpPercap'
                                                                ], 'value': 'continent', 'id': {'type': 'tmp-x', 'index': 1
                                                                }, 'persistence': True
                                                            }, 'type': 'Dropdown', 'namespace': 'dash_core_components'
                                                        }
                                                    }, 'type': 'Row', 'namespace': 'dash_bootstrap_components'
                                                }
                                            ], 'className': 'my-2', 'title': 'x'
                                        }, 'type': 'AccordionItem', 'namespace': 'dash_bootstrap_components'
                                    },
                                    {'props': {'children': [
                                                {'props': {'children': {'props': {'options': ['country', 'year', 'pop', 'continent', 'lifeExp', 'gdpPercap'
                                                                ], 'value': None, 'id': {'type': 'tmp-y', 'index': 1
                                                                }, 'persistence': True
                                                            }, 'type': 'Dropdown', 'namespace': 'dash_core_components'
                                                        }
                                                    }, 'type': 'Row', 'namespace': 'dash_bootstrap_components'
                                                }
                                            ], 'className': 'my-2', 'title': 'y'
                                        }, 'type': 'AccordionItem', 'namespace': 'dash_bootstrap_components'
                                    },
                                    {'props': {'children': [
                                                {'props': {'children': {'props': {'options': ['country', 'year', 'pop', 'continent', 'lifeExp', 'gdpPercap'
                                                                ], 'value': None, 'id': {'type': 'tmp-color', 'index': 1
                                                                }, 'persistence': True
                                                            }, 'type': 'Dropdown', 'namespace': 'dash_core_components'
                                                        }
                                                    }, 'type': 'Row', 'namespace': 'dash_bootstrap_components'
                                                }
                                            ], 'className': 'my-2', 'title': 'color'
                                        }, 'type': 'AccordionItem', 'namespace': 'dash_bootstrap_components'
                                    },
                                    {'props': {'children': [
                                                {'props': {'children': {'props': {'options': ['country', 'year', 'pop', 'continent', 'lifeExp', 'gdpPercap'
                                                                ], 'value': None, 'id': {'type': 'tmp-hover_name', 'index': 1
                                                                }, 'persistence': True
                                                            }, 'type': 'Dropdown', 'namespace': 'dash_core_components'
                                                        }
                                                    }, 'type': 'Row', 'namespace': 'dash_bootstrap_components'
                                                }
                                            ], 'className': 'my-2', 'title': 'hover_name'
                                        }, 'type': 'AccordionItem', 'namespace': 'dash_bootstrap_components'
                                    },
                                    {'props': {'children': [
                                                {'props': {'children': {'props': {'options': ['country', 'year', 'pop', 'continent', 'lifeExp', 'gdpPercap'
                                                                ], 'value': None, 'id': {'type': 'tmp-hover_data', 'index': 1
                                                                }, 'persistence': True
                                                            }, 'type': 'Dropdown', 'namespace': 'dash_core_components'
                                                        }
                                                    }, 'type': 'Row', 'namespace': 'dash_bootstrap_components'
                                                }
                                            ], 'className': 'my-2', 'title': 'hover_data'
                                        }, 'type': 'AccordionItem', 'namespace': 'dash_bootstrap_components'
                                    },
                                    {'props': {'children': [
                                                {'props': {'children': {'props': {'options': ['country', 'year', 'pop', 'continent', 'lifeExp', 'gdpPercap'
                                                                ], 'value': None, 'id': {'type': 'tmp-facet_row', 'index': 1
                                                                }, 'persistence': True
                                                            }, 'type': 'Dropdown', 'namespace': 'dash_core_components'
                                                        }
                                                    }, 'type': 'Row', 'namespace': 'dash_bootstrap_components'
                                                }
                                            ], 'className': 'my-2', 'title': 'facet_row'
                                        }, 'type': 'AccordionItem', 'namespace': 'dash_bootstrap_components'
                                    },
                                    {'props': {'children': [
                                                {'props': {'children': {'props': {'options': ['country', 'year', 'pop', 'continent', 'lifeExp', 'gdpPercap'
                                                                ], 'value': None, 'id': {'type': 'tmp-facet_col', 'index': 1
                                                                }, 'persistence': True
                                                            }, 'type': 'Dropdown', 'namespace': 'dash_core_components'
                                                        }
                                                    }, 'type': 'Row', 'namespace': 'dash_bootstrap_components'
                                                }
                                            ], 'className': 'my-2', 'title': 'facet_col'
                                        }, 'type': 'AccordionItem', 'namespace': 'dash_bootstrap_components'
                                    },
                                    {'props': {'children': [
                                                {'props': {'children': {'props': {'id': {'type': 'tmp-facet_col_wrap', 'index': 1
                                                                }, 'persistence': True, 'placeholder': 'facet_col_wrap', 'type': 'number', 'value': None
                                                            }, 'type': 'Input', 'namespace': 'dash_bootstrap_components'
                                                        }
                                                    }, 'type': 'Row', 'namespace': 'dash_bootstrap_components'
                                                }
                                            ], 'className': 'my-2', 'title': 'facet_col_wrap'
                                        }, 'type': 'AccordionItem', 'namespace': 'dash_bootstrap_components'
                                    },
                                    {'props': {'children': [
                                                {'props': {'children': {'props': {'id': {'type': 'tmp-facet_row_spacing', 'index': 1
                                                                }, 'persistence': True, 'placeholder': 'facet_row_spacing', 'type': 'number', 'value': None
                                                            }, 'type': 'Input', 'namespace': 'dash_bootstrap_components'
                                                        }
                                                    }, 'type': 'Row', 'namespace': 'dash_bootstrap_components'
                                                }
                                            ], 'className': 'my-2', 'title': 'facet_row_spacing'
                                        }, 'type': 'AccordionItem', 'namespace': 'dash_bootstrap_components'
                                    },
                                    {'props': {'children': [
                                                {'props': {'children': {'props': {'id': {'type': 'tmp-facet_col_spacing', 'index': 1
                                                                }, 'persistence': True, 'placeholder': 'facet_col_spacing', 'type': 'number', 'value': None
                                                            }, 'type': 'Input', 'namespace': 'dash_bootstrap_components'
                                                        }
                                                    }, 'type': 'Row', 'namespace': 'dash_bootstrap_components'
                                                }
                                            ], 'className': 'my-2', 'title': 'facet_col_spacing'
                                        }, 'type': 'AccordionItem', 'namespace': 'dash_bootstrap_components'
                                    },
                                    {'props': {'children': [
                                                {'props': {'children': {'props': {'options': ['country', 'year', 'pop', 'continent', 'lifeExp', 'gdpPercap'
                                                                ], 'value': None, 'id': {'type': 'tmp-animation_frame', 'index': 1
                                                                }, 'persistence': True
                                                            }, 'type': 'Dropdown', 'namespace': 'dash_core_components'
                                                        }
                                                    }, 'type': 'Row', 'namespace': 'dash_bootstrap_components'
                                                }
                                            ], 'className': 'my-2', 'title': 'animation_frame'
                                        }, 'type': 'AccordionItem', 'namespace': 'dash_bootstrap_components'
                                    },
                                    {'props': {'children': [
                                                {'props': {'children': {'props': {'options': ['country', 'year', 'pop', 'continent', 'lifeExp', 'gdpPercap'
                                                                ], 'value': None, 'id': {'type': 'tmp-animation_group', 'index': 1
                                                                }, 'persistence': True
                                                            }, 'type': 'Dropdown', 'namespace': 'dash_core_components'
                                                        }
                                                    }, 'type': 'Row', 'namespace': 'dash_bootstrap_components'
                                                }
                                            ], 'className': 'my-2', 'title': 'animation_group'
                                        }, 'type': 'AccordionItem', 'namespace': 'dash_bootstrap_components'
                                    },
                                    {'props': {'children': [
                                                {'props': {'children': {'props': {'id': {'type': 'tmp-orientation', 'index': 1
                                                                }, 'persistence': True, 'placeholder': 'orientation', 'type': 'text', 'value': None
                                                            }, 'type': 'Input', 'namespace': 'dash_bootstrap_components'
                                                        }
                                                    }, 'type': 'Row', 'namespace': 'dash_bootstrap_components'
                                                }
                                            ], 'className': 'my-2', 'title': 'orientation'
                                        }, 'type': 'AccordionItem', 'namespace': 'dash_bootstrap_components'
                                    },
                                    {'props': {'children': [
                                                {'props': {'children': {'props': {'id': {'type': 'tmp-title', 'index': 1
                                                                }, 'persistence': True, 'placeholder': 'title', 'type': 'text', 'value': None
                                                            }, 'type': 'Input', 'namespace': 'dash_bootstrap_components'
                                                        }
                                                    }, 'type': 'Row', 'namespace': 'dash_bootstrap_components'
                                                }
                                            ], 'className': 'my-2', 'title': 'title'
                                        }, 'type': 'AccordionItem', 'namespace': 'dash_bootstrap_components'
                                    },
                                    {'props': {'children': [
                                                {'props': {'children': {'props': {'id': {'type': 'tmp-template', 'index': 1
                                                                }, 'persistence': True, 'placeholder': 'template', 'type': 'text', 'value': None
                                                            }, 'type': 'Input', 'namespace': 'dash_bootstrap_components'
                                                        }
                                                    }, 'type': 'Row', 'namespace': 'dash_bootstrap_components'
                                                }
                                            ], 'className': 'my-2', 'title': 'template'
                                        }, 'type': 'AccordionItem', 'namespace': 'dash_bootstrap_components'
                                    },
                                    {'props': {'children': [
                                                {'props': {'children': {'props': {'id': {'type': 'tmp-width', 'index': 1
                                                                }, 'persistence': True, 'placeholder': 'width', 'type': 'number', 'value': None
                                                            }, 'type': 'Input', 'namespace': 'dash_bootstrap_components'
                                                        }
                                                    }, 'type': 'Row', 'namespace': 'dash_bootstrap_components'
                                                }
                                            ], 'className': 'my-2', 'title': 'width'
                                        }, 'type': 'AccordionItem', 'namespace': 'dash_bootstrap_components'
                                    },
                                    {'props': {'children': [
                                                {'props': {'children': {'props': {'id': {'type': 'tmp-height', 'index': 1
                                                                }, 'persistence': True, 'placeholder': 'height', 'type': 'number', 'value': None
                                                            }, 'type': 'Input', 'namespace': 'dash_bootstrap_components'
                                                        }
                                                    }, 'type': 'Row', 'namespace': 'dash_bootstrap_components'
                                                }
                                            ], 'className': 'my-2', 'title': 'height'
                                        }, 'type': 'AccordionItem', 'namespace': 'dash_bootstrap_components'
                                    }
                                ], 'id': 'accordion-sec-common', 'always_open': True, 'flush': True, 'persistence': True, 'persistence_type': 'session', 'active_item': []
                            }, 'type': 'Accordion', 'namespace': 'dash_bootstrap_components'
                        }
                    ], 'title': 'Common parameters'
                }, 'type': 'AccordionItem', 'namespace': 'dash_bootstrap_components'
            }, 'active_item': 'item-0'
        }, 'type': 'Accordion', 'namespace': 'dash_bootstrap_components'
    },
    {'props': {'children': {'props': {'children': [
                        {'props': {'children': [
                                    {'props': {'children': [
                                                {'props': {'children': {'props': {'options': ['country', 'year', 'pop', 'continent', 'lifeExp', 'gdpPercap'
                                                                ], 'value': None, 'id': {'type': 'tmp-symbol', 'index': 1
                                                                }, 'persistence': True
                                                            }, 'type': 'Dropdown', 'namespace': 'dash_core_components'
                                                        }
                                                    }, 'type': 'Row', 'namespace': 'dash_bootstrap_components'
                                                }
                                            ], 'className': 'my-2', 'title': 'symbol'
                                        }, 'type': 'AccordionItem', 'namespace': 'dash_bootstrap_components'
                                    },
                                    {'props': {'children': [
                                                {'props': {'children': {'props': {'options': ['country', 'year', 'pop', 'continent', 'lifeExp', 'gdpPercap'
                                                                ], 'value': None, 'id': {'type': 'tmp-size', 'index': 1
                                                                }, 'persistence': True
                                                            }, 'type': 'Dropdown', 'namespace': 'dash_core_components'
                                                        }
                                                    }, 'type': 'Row', 'namespace': 'dash_bootstrap_components'
                                                }
                                            ], 'className': 'my-2', 'title': 'size'
                                        }, 'type': 'AccordionItem', 'namespace': 'dash_bootstrap_components'
                                    },
                                    {'props': {'children': [
                                                {'props': {'children': {'props': {'options': ['country', 'year', 'pop', 'continent', 'lifeExp', 'gdpPercap'
                                                                ], 'value': None, 'id': {'type': 'tmp-custom_data', 'index': 1
                                                                }, 'persistence': True
                                                            }, 'type': 'Dropdown', 'namespace': 'dash_core_components'
                                                        }
                                                    }, 'type': 'Row', 'namespace': 'dash_bootstrap_components'
                                                }
                                            ], 'className': 'my-2', 'title': 'custom_data'
                                        }, 'type': 'AccordionItem', 'namespace': 'dash_bootstrap_components'
                                    },
                                    {'props': {'children': [
                                                {'props': {'children': {'props': {'options': ['country', 'year', 'pop', 'continent', 'lifeExp', 'gdpPercap'
                                                                ], 'value': None, 'id': {'type': 'tmp-text', 'index': 1
                                                                }, 'persistence': True
                                                            }, 'type': 'Dropdown', 'namespace': 'dash_core_components'
                                                        }
                                                    }, 'type': 'Row', 'namespace': 'dash_bootstrap_components'
                                                }
                                            ], 'className': 'my-2', 'title': 'text'
                                        }, 'type': 'AccordionItem', 'namespace': 'dash_bootstrap_components'
                                    },
                                    {'props': {'children': [
                                                {'props': {'children': {'props': {'options': ['country', 'year', 'pop', 'continent', 'lifeExp', 'gdpPercap'
                                                                ], 'value': None, 'id': {'type': 'tmp-error_x', 'index': 1
                                                                }, 'persistence': True
                                                            }, 'type': 'Dropdown', 'namespace': 'dash_core_components'
                                                        }
                                                    }, 'type': 'Row', 'namespace': 'dash_bootstrap_components'
                                                }
                                            ], 'className': 'my-2', 'title': 'error_x'
                                        }, 'type': 'AccordionItem', 'namespace': 'dash_bootstrap_components'
                                    },
                                    {'props': {'children': [
                                                {'props': {'children': {'props': {'options': ['country', 'year', 'pop', 'continent', 'lifeExp', 'gdpPercap'
                                                                ], 'value': None, 'id': {'type': 'tmp-error_x_minus', 'index': 1
                                                                }, 'persistence': True
                                                            }, 'type': 'Dropdown', 'namespace': 'dash_core_components'
                                                        }
                                                    }, 'type': 'Row', 'namespace': 'dash_bootstrap_components'
                                                }
                                            ], 'className': 'my-2', 'title': 'error_x_minus'
                                        }, 'type': 'AccordionItem', 'namespace': 'dash_bootstrap_components'
                                    },
                                    {'props': {'children': [
                                                {'props': {'children': {'props': {'options': ['country', 'year', 'pop', 'continent', 'lifeExp', 'gdpPercap'
                                                                ], 'value': None, 'id': {'type': 'tmp-error_y', 'index': 1
                                                                }, 'persistence': True
                                                            }, 'type': 'Dropdown', 'namespace': 'dash_core_components'
                                                        }
                                                    }, 'type': 'Row', 'namespace': 'dash_bootstrap_components'
                                                }
                                            ], 'className': 'my-2', 'title': 'error_y'
                                        }, 'type': 'AccordionItem', 'namespace': 'dash_bootstrap_components'
                                    },
                                    {'props': {'children': [
                                                {'props': {'children': {'props': {'options': ['country', 'year', 'pop', 'continent', 'lifeExp', 'gdpPercap'
                                                                ], 'value': None, 'id': {'type': 'tmp-error_y_minus', 'index': 1
                                                                }, 'persistence': True
                                                            }, 'type': 'Dropdown', 'namespace': 'dash_core_components'
                                                        }
                                                    }, 'type': 'Row', 'namespace': 'dash_bootstrap_components'
                                                }
                                            ], 'className': 'my-2', 'title': 'error_y_minus'
                                        }, 'type': 'AccordionItem', 'namespace': 'dash_bootstrap_components'
                                    },
                                    {'props': {'children': [
                                                {'props': {'children': {'props': {'id': {'type': 'tmp-opacity', 'index': 1
                                                                }, 'persistence': True, 'placeholder': 'opacity', 'type': 'number', 'value': None
                                                            }, 'type': 'Input', 'namespace': 'dash_bootstrap_components'
                                                        }
                                                    }, 'type': 'Row', 'namespace': 'dash_bootstrap_components'
                                                }
                                            ], 'className': 'my-2', 'title': 'opacity'
                                        }, 'type': 'AccordionItem', 'namespace': 'dash_bootstrap_components'
                                    },
                                    {'props': {'children': [
                                                {'props': {'children': {'props': {'id': {'type': 'tmp-size_max', 'index': 1
                                                                }, 'persistence': True, 'placeholder': 'size_max', 'type': 'number', 'value': None
                                                            }, 'type': 'Input', 'namespace': 'dash_bootstrap_components'
                                                        }
                                                    }, 'type': 'Row', 'namespace': 'dash_bootstrap_components'
                                                }
                                            ], 'className': 'my-2', 'title': 'size_max'
                                        }, 'type': 'AccordionItem', 'namespace': 'dash_bootstrap_components'
                                    },
                                    {'props': {'children': [
                                                {'props': {'children': {'props': {'id': {'type': 'tmp-marginal_x', 'index': 1
                                                                }, 'persistence': True, 'placeholder': 'marginal_x', 'type': 'text', 'value': None
                                                            }, 'type': 'Input', 'namespace': 'dash_bootstrap_components'
                                                        }
                                                    }, 'type': 'Row', 'namespace': 'dash_bootstrap_components'
                                                }
                                            ], 'className': 'my-2', 'title': 'marginal_x'
                                        }, 'type': 'AccordionItem', 'namespace': 'dash_bootstrap_components'
                                    },
                                    {'props': {'children': [
                                                {'props': {'children': {'props': {'id': {'type': 'tmp-marginal_y', 'index': 1
                                                                }, 'persistence': True, 'placeholder': 'marginal_y', 'type': 'text', 'value': None
                                                            }, 'type': 'Input', 'namespace': 'dash_bootstrap_components'
                                                        }
                                                    }, 'type': 'Row', 'namespace': 'dash_bootstrap_components'
                                                }
                                            ], 'className': 'my-2', 'title': 'marginal_y'
                                        }, 'type': 'AccordionItem', 'namespace': 'dash_bootstrap_components'
                                    },
                                    {'props': {'children': [
                                                {'props': {'children': {'props': {'id': {'type': 'tmp-trendline', 'index': 1
                                                                }, 'persistence': True, 'placeholder': 'trendline', 'type': 'text', 'value': None
                                                            }, 'type': 'Input', 'namespace': 'dash_bootstrap_components'
                                                        }
                                                    }, 'type': 'Row', 'namespace': 'dash_bootstrap_components'
                                                }
                                            ], 'className': 'my-2', 'title': 'trendline'
                                        }, 'type': 'AccordionItem', 'namespace': 'dash_bootstrap_components'
                                    },
                                    {'props': {'children': [
                                                {'props': {'children': {'props': {'id': {'type': 'tmp-trendline_color_override', 'index': 1
                                                                }, 'persistence': True, 'placeholder': 'trendline_color_override', 'type': 'text', 'value': None
                                                            }, 'type': 'Input', 'namespace': 'dash_bootstrap_components'
                                                        }
                                                    }, 'type': 'Row', 'namespace': 'dash_bootstrap_components'
                                                }
                                            ], 'className': 'my-2', 'title': 'trendline_color_override'
                                        }, 'type': 'AccordionItem', 'namespace': 'dash_bootstrap_components'
                                    },
                                    {'props': {'children': [
                                                {'props': {'children': {'props': {'id': {'type': 'tmp-trendline_scope', 'index': 1
                                                                }, 'persistence': True, 'placeholder': 'trendline_scope', 'type': 'text', 'value': None
                                                            }, 'type': 'Input', 'namespace': 'dash_bootstrap_components'
                                                        }
                                                    }, 'type': 'Row', 'namespace': 'dash_bootstrap_components'
                                                }
                                            ], 'className': 'my-2', 'title': 'trendline_scope'
                                        }, 'type': 'AccordionItem', 'namespace': 'dash_bootstrap_components'
                                    },
                                    {'props': {'children': [
                                                {'props': {'children': {'props': {'id': {'type': 'tmp-render_mode', 'index': 1
                                                                }, 'persistence': True, 'placeholder': 'render_mode', 'type': 'text', 'value': None
                                                            }, 'type': 'Input', 'namespace': 'dash_bootstrap_components'
                                                        }
                                                    }, 'type': 'Row', 'namespace': 'dash_bootstrap_components'
                                                }
                                            ], 'className': 'my-2', 'title': 'render_mode'
                                        }, 'type': 'AccordionItem', 'namespace': 'dash_bootstrap_components'
                                    }
                                ], 'id': 'accordion', 'always_open': True, 'flush': True, 'persistence': True, 'persistence_type': 'session', 'active_item': ['item-0'
                                ]
                            }, 'type': 'Accordion', 'namespace': 'dash_bootstrap_components'
                        }
                    ], 'title': 'Scatter specific parameters'
                }, 'type': 'AccordionItem', 'namespace': 'dash_bootstrap_components'
            }, 'active_item': 'item-0'
        }, 'type': 'Accordion', 'namespace': 'dash_bootstrap_components'
    }
]

# %%
children[0]["props"]["children"]["props"]["children"][0]["props"]["children"][0]
# Out:
# {'props': {'children': [{'props': {'children': {'props': {'options': ['country',
#         'year',
#         'pop',
#         'continent',
#         'lifeExp',
#         'gdpPercap'],
#        'value': 'continent',
#        'id': {'type': 'tmp-x', 'index': 1},
#        'persistence': True},
#       'type': 'Dropdown',
#       'namespace': 'dash_core_components'}},
#     'type': 'Row',
#     'namespace': 'dash_bootstrap_components'}],
#   'className': 'my-2',
#   'title': 'x'},
#  'type': 'AccordionItem',
#  'namespace': 'dash_bootstrap_components'}

# %%
accordion_secondary_common_params = children[0]["props"]["children"]["props"]["children"][0]["props"]["children"]
accordion_secondary_common_params
# # accordion_secondary_common_params = children[1]["props"]["children"]
# if accordion_secondary_common_params:
# print("TOTO")
[
    param["props"]["children"][0]["props"]["children"]
    for param in accordion_secondary_common_params
]
# Out:
# [{'props': {'options': ['country',
#     'year',
#     'pop',
#     'continent',
#     'lifeExp',
#     'gdpPercap'],
#    'value': 'continent',
#    'id': {'type': 'tmp-x', 'index': 1},
#    'persistence': True},
#   'type': 'Dropdown',
#   'namespace': 'dash_core_components'},
#  {'props': {'options': ['country',
#     'year',
#     'pop',
#     'continent',
#     'lifeExp',
#     'gdpPercap'],
#    'value': None,
#    'id': {'type': 'tmp-y', 'index': 1},
#    'persistence': True},
#   'type': 'Dropdown',
#   'namespace': 'dash_core_components'},
#  {'props': {'options': ['country',
#     'year',
#     'pop',
#     'continent',
#     'lifeExp',
#     'gdpPercap'],
#    'value': None,
#    'id': {'type': 'tmp-color', 'index': 1},
#    'persistence': True},
#   'type': 'Dropdown',
#   'namespace': 'dash_core_components'},
#  {'props': {'options': ['country',
#     'year',
#     'pop',
#     'continent',
#     'lifeExp',
#     'gdpPercap'],
#    'value': None,
# ...

# %%
accordion_secondary_common_params = children[1]
accordion_secondary_common_params
# # accordion_secondary_common_params = children[1]["props"]["children"]
# if accordion_secondary_common_params:
# print("TOTO")
# [
#     param["props"]["children"][0]["props"]["children"]
#     for param in accordion_secondary_common_params
# ]
# Out:
# {'props': {'children': {'props': {'children': [{'props': {'children': [{'props': {'children': [{'props': {'children': {'props': {'options': ['country',
#                 'year',
#                 'pop',
#                 'continent',
#                 'lifeExp',
#                 'gdpPercap'],
#                'value': None,
#                'id': {'type': 'tmp-symbol', 'index': 1},
#                'persistence': True},
#               'type': 'Dropdown',
#               'namespace': 'dash_core_components'}},
#             'type': 'Row',
#             'namespace': 'dash_bootstrap_components'}],
#           'className': 'my-2',
#           'title': 'symbol'},
#          'type': 'AccordionItem',
#          'namespace': 'dash_bootstrap_components'},
#         {'props': {'children': [{'props': {'children': {'props': {'options': ['country',
#                 'year',
#                 'pop',
#                 'continent',
#                 'lifeExp',
#                 'gdpPercap'],
# ...

# %%
accordion_secondary_common_params = children[1]["props"]["children"]["props"]["children"][0]["props"]["children"]
accordion_secondary_common_params
# # accordion_secondary_common_params = children[1]["props"]["children"]
# if accordion_secondary_common_params:
# print("TOTO")
[
    param["props"]["children"][0]["props"]["children"]
    for param in accordion_secondary_common_params
]
# Out:
# [{'props': {'options': ['country',
#     'year',
#     'pop',
#     'continent',
#     'lifeExp',
#     'gdpPercap'],
#    'value': None,
#    'id': {'type': 'tmp-symbol', 'index': 1},
#    'persistence': True},
#   'type': 'Dropdown',
#   'namespace': 'dash_core_components'},
#  {'props': {'options': ['country',
#     'year',
#     'pop',
#     'continent',
#     'lifeExp',
#     'gdpPercap'],
#    'value': None,
#    'id': {'type': 'tmp-size', 'index': 1},
#    'persistence': True},
#   'type': 'Dropdown',
#   'namespace': 'dash_core_components'},
#  {'props': {'options': ['country',
#     'year',
#     'pop',
#     'continent',
#     'lifeExp',
#     'gdpPercap'],
#    'value': None,
#    'id': {'type': 'tmp-custom_data', 'index': 1},
#    'persistence': True},
#   'type': 'Dropdown',
#   'namespace': 'dash_core_components'},
#  {'props': {'options': ['country',
#     'year',
#     'pop',
#     'continent',
#     'lifeExp',
#     'gdpPercap'],
#    'value': None,
# ...
